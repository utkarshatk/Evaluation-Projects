# %% [markdown]
# # Zomato Restaurant Project

# %% [markdown]
# ### Problem Statement:
#
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.

# %% [markdown]
# ### Data Storage:
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
#
#  Country code
#  Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the
# following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
# • Restaurant Name: Name of the restaurant
# • Country Code: Country in which restaurant is located
# • City: City in which restaurant is located
# • Address: Address of the restaurant
# • Locality: Location in the city
# • Locality Verbose: Detailed description of the locality
# • Longitude: Longitude coordinate of the restaurant&#39;s location
# • Latitude: Latitude coordinate of the restaurant&#39;s location
# • Cuisines: Cuisines offered by the restaurant
# • Average Cost for two: Cost for two people in different currencies ��
# • Currency: Currency of the country
# • Has Table booking: yes/no
# • Has Online delivery: yes/ no
# • Is delivering: yes/ no
# • Switch to order menu: yes/no
# • Price range: range of price of food
# • Aggregate Rating: Average rating out of 5
# • Rating color: depending upon the average rating color
# • Rating text: text on the basis of rating of rating
# • Votes: Number of ratings casted by people
#
# #### Problem statement : In this dataset predict 2 things –
# 1) Average Cost for two
# 2) Price range

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
zomato=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv',encoding = "ISO-8859-1")

# %%
Country=pd.read_excel(r'D:\Downloads\Country-Code.xlsx')

# %%
All=pd.merge(zomato,Country)

# %%
All.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
All.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
All.sample(10)
# Out:
#       Restaurant ID              Restaurant Name  Country Code  \
# 8969       18383535           Sugar Daddy Bakers             1
# 2140       18265082           Teddy Choco Studio             1
# 5063       18489807      Dolphin - The Food Cafe             1
# 1601         302041                         Kaza             1
# 7666         310581           Kamal Chat Bhandar             1
# 4062       18428622              D Brown Affairs             1
# 177        17316381            Atlas World Grill           216
# 4042         306595                Dee The Baker             1
# 8716       18289230                  Public Cafe             1
# 2796         301581  Coffee Shop - Centaur Hotel             1
#
#                         City  \
# 8969                   Noida
# 2140                 Gurgaon
# 5063               New Delhi
# 1601                 Gurgaon
# 7666               New Delhi
# 4062               New Delhi
# 177   Cedar Rapids/Iowa City
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
All.shape
# Out:
# (9551, 22)

# %% [markdown]
# We can see that our dataset is having 9551 rows and 22 columns.

# %%
All.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# - We can see the above mentioned columns that are present in our dataset.

# %% [markdown]
# Columns Description:
#
#     • Restaurant Id: Unique id of every restaurant across various cities of the world
#     • Restaurant Name: Name of the restaurant
#     • Country Code: Country in which restaurant is located
#     • City: City in which restaurant is located
#     • Address: Address of the restaurant
#     • Locality: Location in the city
#     • Locality Verbose: Detailed description of the locality
#     • Longitude: Longitude coordinate of the restaurant's location
#     • Latitude: Latitude coordinate of the restaurant's location
#     • Cuisines: Cuisines offered by the restaurant
#     • Average Cost for two: Cost for two people in different currencies ��
#     • Currency: Currency of the country
#     • Has Table booking: yes/no
#     • Has Online delivery: yes/ no
#     • Is delivering: yes/ no
#     • Switch to order menu: yes/no
#     • Price range: range of price of food
#     • Aggregate Rating: Average rating out of 5
#     • Rating color: depending upon the average rating color
#     • Rating text: text on the basis of rating of rating
#     • Votes: Number of ratings casted by people

# %% [markdown]
# - We have 2 target variables i.e dependent variables
# 1) Average Cost for two
# 2) Price range
#
# - And remaining 20 are our independent variables , our feature columns.

# %%
# Let us check the datatypes of all the columns:
All.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
# Lets us check the information and count of dtypes in the columns:
All.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# - We have 8 numerical datatypes and 14 object datatypes.
#
# - Also we can see that column 'Cuisines' shows us 9542 non-null values and other columns have 9551 non-null values that means we have some missng data in Cuisines column.

# %% [markdown]
# ### We will have to make 2 models, 1 to predict "Average Cost for two" and 2nd model to predict "Price range".

# %% [markdown]
# # Checking Null values

# %%
All.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# - We can see that there are 9 missing values in column "Cuisines", we will fill this missing values using mean function.

# %% [markdown]
# # Unique values

# %%
All.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %% [markdown]
# - We can see that 'Restaurant ID' has 9551 unique data, which has no much relevant input to our dataset, so we will be dropping this column.

# %% [markdown]
# #### Also we can see our target variables "Average Cost for two" and "Price range" have 140 and 4 unique values, this means that it is a problem of Regression.

# %%
All.drop('Restaurant ID',axis=1,inplace=True)

# %% [markdown]
# # Let us check the Duplicate values

# %%
All.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - We can see that there are no duplicate values in our dataset.

# %%
# Let us check the value counts of all data:

for columns in All:
    print(columns)
    print(All[columns].value_counts())
    print("="*120)
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
# ...
# Country Code
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
# ...
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
#                 ...
# Huskisson          1
# Panchkula          1
# Forrest            1
# Flaxton            1
# Chatham-Kent       1
# Name: City, Length: 141, dtype: int64
# ...

# %% [markdown]
# # Let us seperate numerical and object datatypes

# %%
object_cols=[]

for i in All.dtypes.index:
    if All.dtypes[i] == 'object':
        object_cols.append(i)
object_cols
# Out:
# ['Restaurant Name',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Rating color',
#  'Rating text',
#  'Country']

# %%
numerical_cols=[]

for i in All.dtypes.index:
    if All.dtypes[i] != 'object':
        numerical_cols.append(i)
numerical_cols
# Out:
# ['Country Code',
#  'Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %%
# Let us first  visualize the null values using heatmap:
sns.heatmap(All.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# - The % of missing data is very less so we cannot visualize it.

# %% [markdown]
# # Filling the Missing data

# %%
df=pd.DataFrame()
df['Cuisines'] = All['Cuisines'].fillna(All['Cuisines'].mode()[0])

# %%
df.head()
# Out:
#                            Cuisines
# 0        French, Japanese, Desserts
# 1                          Japanese
# 2  Seafood, Asian, Filipino, Indian
# 3                   Japanese, Sushi
# 4                  Japanese, Korean

# %%
# We have filled the missing data, now lets check if there is any more null values in the dataset.

df.isna().sum()
# Out:
# Cuisines    0
# dtype: int64

# %%
All.isnull().sum()
# Out:
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
All['Cuisines']=df['Cuisines']

# %%
All.isnull().sum()
# Out:
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# - Now there are no missing values.

# %%
All.dropna(inplace=True)
All.shape
# Out:
# (9551, 21)

# %% [markdown]
# - We have also dropped out the columns which had NAN values in it.

# %% [markdown]
# # Statistical Data:

# %%
All.describe()
# Out:
#        Country Code    Longitude     Latitude  Average Cost for two  \
# count   9551.000000  9551.000000  9551.000000           9551.000000
# mean      18.365616    64.126574    25.854381           1199.210763
# std       56.750546    41.467058    11.007935          16121.183073
# min        1.000000  -157.948486   -41.330428              0.000000
# 25%        1.000000    77.081343    28.478713            250.000000
# 50%        1.000000    77.191964    28.570469            400.000000
# 75%        1.000000    77.282006    28.642758            700.000000
# max      216.000000   174.832089    55.976980         800000.000000
#
#        Price range  Aggregate rating         Votes
# count  9551.000000       9551.000000   9551.000000
# mean      1.804837          2.666370    156.909748
# std       0.905609          1.516378    430.169145
# min       1.000000          0.000000      0.000000
# 25%       1.000000          2.500000      5.000000
# ...

# %% [markdown]
# - We can see that all the numerical columns has count as 9551.
#
# - Minimum value is 0 and maximum value is 800000.

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()
All[object_cols]= All[object_cols].apply(LE.fit_transform)

# %%
All.head()
# Out:
#    Restaurant Name  Country Code  City  Address  Locality  Locality Verbose  \
# 0             3749           162    73     8685       171               172
# 1             3173           162    73     6055       593               601
# 2             2897           162    75     4684       308               314
# 3             4707           162    75     8690       862               875
# 4             5523           162    75     8689       862               875
#
#     Longitude   Latitude  Cuisines  Average Cost for two  ...  \
# 0  121.027535  14.565443         0                  1100  ...
# 1  121.014101  14.553708         0                  1200  ...
# 2  121.056831  14.581404         0                  4000  ...
# 3  121.056475  14.585318         0                  1500  ...
# 4  121.057508  14.584450         0                  1500  ...
#
#    Has Table booking  Has Online delivery  Is delivering now  \
# 0                  1                    0                  0
# ...

# %% [markdown]
# # Correlation

# %%
All.corr()
# Out:
#                       Restaurant Name  Country Code      City   Address  \
# Restaurant Name              1.000000      0.020012 -0.001399  0.000763
# Country Code                 0.020012      1.000000 -0.181728 -0.220342
# City                        -0.001399     -0.181728  1.000000 -0.019763
# Address                      0.000763     -0.220342 -0.019763  1.000000
# Locality                     0.004322     -0.120075  0.096444  0.159555
# Locality Verbose             0.004281     -0.117543  0.093142  0.160495
# Longitude                   -0.001920     -0.698299  0.117391  0.185801
# Latitude                     0.009922      0.019792 -0.004301 -0.038654
# Cuisines                          NaN           NaN       NaN       NaN
# Average Cost for two         0.019241      0.043225 -0.028838  0.022749
# Currency                     0.009669     -0.033466 -0.071996  0.069499
# Has Table booking            0.041173     -0.061682 -0.003762  0.006428
# ...

# %% [markdown]
# # Correlation using Heatmap

# %%
plt.figure(figsize=(25,25))
sns.heatmap(All.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.1g',linecolor="black", annot = True, annot_kws={'size':10},cmap="cool")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize=(15,10))
All.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='indigo')
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('Correlation between label and feature using bar plot',fontsize=18)
plt.show()

# %% [markdown]
# - We can clearly see that 'Switch to order menu' and 'Cuisines' do not correlate with our target variable.

# %% [markdown]
# # Data Visualization

# %%
All.columns
# Out:
# Index(['Restaurant Name', 'Country Code', 'City', 'Address', 'Locality',
#        'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
All.columns=[x.replace(" ","_")for x in All.columns ]

# %%
A=All[['Restaurant_Name', 'Country_Code', 'City',
         'Longitude', 'Latitude', 'Cuisines',
       'Average_Cost_for_two', 'Currency', 'Has_Table_booking',
       'Has_Online_delivery', 'Is_delivering_now', 'Switch_to_order_menu',
       'Price_range', 'Aggregate_rating', 'Rating_color', 'Rating_text',
       'Votes', 'Country']]

# %% [markdown]
# #### Countplot

# %%
for i in ['Price_range','Has_Online_delivery','Has_Table_booking','Switch_to_order_menu','Rating_color','Rating_text','Aggregate_rating']:
    A[i].unique()
    fig, ax =plt.subplots()
    fig.set_size_inches(12,8)
    sns.countplot(x=i,data=A)

# %% [markdown]
# #### Lineplot

# %%
plt.figure(figsize=[18,12])

plt.subplot(2,2,1)
plt.title('Comparision between Has_Table_booking & Price_range')
sns.lineplot(A['Has_Table_booking'],A['Price_range'],hue=A['Average_Cost_for_two'],palette='coolwarm')

plt.subplot(2,2,2)
plt.title('Comparision between Restaurant_Name and City')
sns.lineplot(A['Restaurant_Name'],A['City'],hue=A['Average_Cost_for_two'],palette='cool')

plt.subplot(2,2,3)
plt.title('Comparision between Has_Online_delivery and Is_delivering_now')
sns.lineplot(A['Has_Online_delivery'],A['Is_delivering_now'],hue=A['Average_Cost_for_two'],palette='spring')

plt.subplot(2,2,4)
plt.title('Comparision between Aggregate_rating and Votes')
sns.lineplot(A['Aggregate_rating'],A['Votes'],hue=A['Average_Cost_for_two'],palette='hsv')
plt.show()

# %% [markdown]
# #### Scatterplot

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.scatterplot(A['Has_Table_booking'],A['Price_range'],hue=A['Average_Cost_for_two'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.scatterplot(A['Restaurant_Name'],A['City'],hue=A['Average_Cost_for_two'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.scatterplot(A['Has_Online_delivery'],A['Is_delivering_now'],hue=A['Average_Cost_for_two'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.scatterplot(A['Aggregate_rating'],A['Votes'],hue=A['Average_Cost_for_two'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.scatterplot(A['Country'],A['Country_Code'],hue=A['Average_Cost_for_two'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.scatterplot(A['Longitude'],A['Latitude'],hue=A['Average_Cost_for_two'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.scatterplot(A['Cuisines'],A['Currency'],hue=A['Average_Cost_for_two'])
plt.show()

# %% [markdown]
# # Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler

#Separate Label and Features
x=A.drop('Average_Cost_for_two',axis=1)
y=A.Average_Cost_for_two

scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x.head()
# Out:
#    Restaurant_Name  Country_Code      City  Longitude  Latitude  Cuisines  \
# 0         0.044706      2.531111 -0.228533   1.372269 -1.025581       0.0
# 1        -0.224101      2.531111 -0.228533   1.371945 -1.026647       0.0
# 2        -0.352904      2.531111 -0.142317   1.372975 -1.024131       0.0
# 3         0.491783      2.531111 -0.142317   1.372966 -1.023775       0.0
# 4         0.872592      2.531111 -0.142317   1.372991 -1.023854       0.0
#
#    Currency  Has_Table_booking  Has_Online_delivery  Is_delivering_now  \
# 0 -4.351046           2.692181            -0.587547          -0.059771
# 1 -4.351046           2.692181            -0.587547          -0.059771
# 2 -4.351046           2.692181            -0.587547          -0.059771
# 3 -4.351046          -0.371446            -0.587547          -0.059771
# 4 -4.351046           2.692181            -0.587547          -0.059771
#
#    Switch_to_order_menu  Price_range  Aggregate_rating  Rating_color  \
# ...

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

#Checking VIF
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#     VIF values              Features
# 0     1.005057       Restaurant_Name
# 1    47.324186          Country_Code
# 2     1.066862                  City
# 3     5.054954             Longitude
# 4     3.022828              Latitude
# 5          NaN              Cuisines
# 6     1.292999              Currency
# 7     1.462581     Has_Table_booking
# 8     1.160022   Has_Online_delivery
# 9     1.013026     Is_delivering_now
# 10         NaN  Switch_to_order_menu
# 11    1.948889           Price_range
# 12    1.787027      Aggregate_rating
# 13    1.230539          Rating_color
# 14    1.337950           Rating_text
# 15    1.267836                 Votes
# 16   64.837582               Country

# %% [markdown]
# We can see that 'Country','Country_Code' have high VIF values, so we will drop them.

# %%
x.drop('Country',axis=1,inplace=True)

# %%
x.drop('Country_Code',axis=1,inplace=True)

# %%
#Checking VIF again

vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#     VIF values              Features
# 0     1.004940       Restaurant_Name
# 1     1.062061                  City
# 2     1.317619             Longitude
# 3     1.096472              Latitude
# 4          NaN              Cuisines
# 5     1.190379              Currency
# 6     1.430183     Has_Table_booking
# 7     1.144658   Has_Online_delivery
# 8     1.013005     Is_delivering_now
# 9          NaN  Switch_to_order_menu
# 10    1.856719           Price_range
# 11    1.709944      Aggregate_rating
# 12    1.210071          Rating_color
# 13    1.291149           Rating_text
# 14    1.244195                 Votes

# %% [markdown]
# 'Cuisines' and 'Switch_to_order_menu' columns has VIF value as NAN, so we will drop them.

# %%
x.drop(columns=['Switch_to_order_menu','Cuisines'],axis=1,inplace=True)

# %% [markdown]
# # Model Building 1

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state =i)
    RFG = RandomForestRegressor()
    RFG.fit(x_train, y_train)
    pred = RFG.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.9670979810657656  on Random_state  61

# %%
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.model_selection import GridSearchCV, cross_val_score

# %% [markdown]
# # Random Forest Regressor

# %%
# Checking R2 score for Random Forest Regressor
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)

# prediction
predRFR=RFR.predict(x_test)
print('R2_Score:',r2_score(y_test,predRFR))
print('MAE:',mean_absolute_error(y_test, predRFR))
print('MSE:',mean_squared_error(y_test, predRFR))
print("RMSE:",np.sqrt(mean_squared_error(y_test, predRFR)))
# Checking cv score 
print(cross_val_score(RFR,x,y,cv=5).mean())
# Out:
# R2_Score: 0.7219304252012677
# MAE: 470.3626064200977
# MSE: 97459658.19207095
# RMSE: 9872.165830863607
# -1524.0236323544905

# %% [markdown]
# # KNNeighbors Regressor

# %%
# Checking R2 score for Stochastic KNN Regressor
knn=KNN()
knn.fit(x_train,y_train)

# prediction
predknn=knn.predict(x_test)
print('R2_Score:',r2_score(y_test,predknn))
print('MAE:',mean_absolute_error(y_test, predknn))
print('MSE:',mean_squared_error(y_test, predknn))
print("RMSE:",np.sqrt(mean_squared_error(y_test, predknn)))
# Checking cv score 
print(cross_val_score(knn,x,y,cv=5).mean())
# Out:
# R2_Score: 0.5394240821065666
# MAE: 555.1078157711096
# MSE: 161425684.78368458
# RMSE: 12705.340797620684
# -105.92523645372228

# %% [markdown]
# # GradientBoosting Regressor

# %%
# Checking R2 score for GradientBoosting Regressor
GB=GradientBoostingRegressor()
GB.fit(x_train,y_train)

# prediction
predGB=GB.predict(x_test)
print('R2_Score:',r2_score(y_test,predGB))
print('MAE:',mean_absolute_error(y_test, predGB))
print('MSE:',mean_squared_error(y_test, predGB))
print("RMSE:",np.sqrt(mean_squared_error(y_test, predGB)))
# Checking cv score 

print(cross_val_score(GB,x,y,cv=5).mean())
# Out:
# R2_Score: 0.6142660530010671
# MAE: 531.9372645418
# MSE: 135194577.3096705
# RMSE: 11627.320297887665
# -1493.416775036199

# %% [markdown]
# # BaggingRegressor

# %%
# Checking R2 score for BaggingRegressor
BR=BaggingRegressor()
BR.fit(x_train,y_train)

# prediction
predBR=BR.predict(x_test)
print('R2_Score:',r2_score(y_test,predBR))
print('MAE:',mean_absolute_error(y_test, predBR))
print('MSE:',mean_squared_error(y_test, predBR))
print("RMSE:",np.sqrt(mean_squared_error(y_test, predBR)))
# Checking cv score
print(cross_val_score(BR,x,y,cv=5).mean())
# Out:
# R2_Score: 0.6075563573585219
# MAE: 552.51346824843
# MSE: 137546235.68282622
# RMSE: 11728.010729992799
# -1485.3445889428392

# %% [markdown]
# # AdaBoostRegressor

# %%
ABR=AdaBoostRegressor()

ABR.fit(x_train,y_train)
# prediction
predABR=ABR.predict(x_test)
print('R2_Score:',r2_score(y_test,predABR))
print('MAE:',mean_absolute_error(y_test, predABR))
print('MSE:',mean_squared_error(y_test, predABR))
print("RMSE:",np.sqrt(mean_squared_error(y_test, predABR)))
# Checking cv score
print(cross_val_score(ABR,x,y,cv=5).mean())
# Out:
# R2_Score: 0.23652098532382504
# MAE: 7453.7206032859685
# MSE: 267589159.51526237
# RMSE: 16358.15269262585
# -887.8196737570646

# %% [markdown]
# # Hyper parameter tuning

# %% [markdown]
# From all above regression models, I am selecting Random Forest Regressor as my best model

# %%
parameter={'n_estimators':[1,3,4,5],
          'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
          'max_features' : ['sqrt', 'log2', None],
          'random_state':[100,150,200,250]}

# %%
GCV=GridSearchCV(Random ForestRegressor(),parameter,cv=7)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [1, 3, 4, 5],
#                          'random_state': [100, 150, 200, 250]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_features': None,
#  'n_estimators': 3,
#  'random_state': 200}

# %%
Zomato_model = RandomForestRegressor(criterion= 'friedman_mse',max_features= None,n_estimators= 3,random_state= 200)
Zomato_model.fit(x_train, y_train)
pred = Zomato_model.predict(x_test)
print("RMSE value:",np.sqrt(mean_squared_error(y_test, pred)))
print('R2_Score:',r2_score(y_test,pred)*100)
# Out:
# RMSE value: 8382.789568178776
# R2_Score: 79.950399778846

# %% [markdown]
# # Saving the model

# %%
import pickle

# %%
filename = "Final_Zomato_model_for_Average2.pkl"
pickle.dump(filename, open(filename,'wb'))

# %% [markdown]
# # Loading The Model

# %%
loadmodel = pickle.load(open('Final_Zomato_model_for_Average2.pkl', 'rb'))

# %%
pred = Zomato_model.predict(x_test)
a = np.array(y_test)
df_final = pd.DataFrame({"Original":a,"Predicted":pred},index=range(len(a)))
df_final
# Out:
#       Original    Predicted
# 0         2000  2266.666667
# 1          250   283.333333
# 2          500   583.333333
# 3          250   233.333333
# 4          500   500.000000
# ...        ...          ...
# 2861       800  1133.333333
# 2862        70    86.666667
# 2863       100   150.000000
# 2864       250   283.333333
# 2865       200   266.666667
#
# [2866 rows x 2 columns]

# %% [markdown]
# # Plot the result

# %%
plt.figure(figsize=(10,10))
sns.regplot(y_test,pred,color='indigo')
plt.xlabel('Actual ',fontsize=15)
plt.ylabel('Predicted',fontsize=15)
plt.title("RandomForestRegressor")
plt.show()

# %% [markdown]
# # Now let us predict the 'Price Range' from our data using Regression Model

# %%
#Finding relation with Price Range 
plt.figure(figsize=(30,25))
sns.heatmap(All.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.1g',linecolor="black", annot = True, annot_kws={'size':10},cmap="hsv")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize=(20,10))
All.corr()['Price_range'].sort_values(ascending=False).drop(['Price_range']).plot(kind='bar',color='purple')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Target',fontsize=14)
plt.title('correlation between label and feature using bar plot',fontsize=18)
plt.show()

# %% [markdown]
# # Separating the features and label variables into X and Y

# %%
X = All.drop("Price_range", axis=1)
Y = All["Price_range"]

# %% [markdown]
# # Feature Scaling using Standard Scalarization

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.head()
# Out:
#    Restaurant_Name  Country_Code      City   Address  Locality  \
# 0         0.044706      2.531111 -0.228533  1.614667 -1.542278
# 1        -0.224101      2.531111 -0.228533  0.589558 -0.206201
# 2        -0.352904      2.531111 -0.142317  0.055177 -1.108528
# 3         0.491783      2.531111 -0.142317  1.616615  0.645470
# 4         0.872592      2.531111 -0.142317  1.616226  0.645470
#
#    Locality_Verbose  Longitude  Latitude  Cuisines  Average_Cost_for_two  \
# 0         -1.523333   1.372269 -1.025581       0.0             -0.006154
# 1         -0.230035   1.371945 -1.026647       0.0              0.000049
# 2         -1.095249   1.372975 -1.024131       0.0              0.173743
# 3          0.595987   1.372966 -1.023775       0.0              0.018659
# 4          0.595987   1.372991 -1.023854       0.0              0.018659
#
#    Currency  Has_Table_booking  Has_Online_delivery  Is_delivering_now  \
# 0 -4.351046           2.692181            -0.587547          -0.059771
# ...

# %% [markdown]
# # Modeling 2

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=.30, random_state =i)
    RFG = RandomForestRegressor()
    RFG.fit(X_train, Y_train)
    pred = RFG.predict(X_test)
    acc=r2_score(Y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.9875439872347891  on Random_state  140

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.30,random_state=maxRS)

# %%
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# # Random Forest Regressor

# %%
# Checking R2 score for Random Forest Regressor
RFR=RandomForestRegressor()
RFR.fit(X_train,Y_train)

# prediction
predRFR=RFR.predict(X_test)
print('R2_Score:',r2_score(Y_test,predRFR))
print('MAE:',mean_absolute_error(Y_test, predRFR))
print('MSE:',mean_squared_error(Y_test, predRFR))
print("RMSE:",np.sqrt(mean_squared_error(Y_test, predRFR)))
# Checking cv score 
print(cross_val_score(RFR,X,Y,cv=5).mean())
# Out:
# R2_Score: 0.9872155687535796
# MAE: 0.02710746685275645
# MSE: 0.010717899511514306
# RMSE: 0.10352728872869368
# 0.8638442896811431

# %% [markdown]
# # KNNeighbors Regressor

# %%
# Checking R2 score for Stochastic KNN Regressor
knn=KNN()
knn.fit(X_train,Y_train)

# prediction
predknn=knn.predict(X_test)
print('R2_Score:',r2_score(Y_test,predknn))
print('MAE:',mean_absolute_error(Y_test, predknn))
print('MSE:',mean_squared_error(Y_test, predknn))
print("RMSE:",np.sqrt(mean_squared_error(Y_test, predknn)))
# Checking cv score 
print(cross_val_score(knn,X,Y,cv=5).mean())
# Out:
# R2_Score: 0.5096072385763095
# MAE: 0.47725052337752966
# MSE: 0.41112351709699935
# RMSE: 0.6411891429968223
# 0.35013622694529245

# %% [markdown]
# # GradientBoosting Regressor

# %%
# Checking R2 score for GradientBoosting Regressor
GB=GradientBoostingRegressor()
GB.fit(X_train,Y_train)

# prediction
predGB=GB.predict(X_test)
print('R2_Score:',r2_score(Y_test,predGB))
print('MAE:',mean_absolute_error(Y_test, predGB))
print('MSE:',mean_squared_error(Y_test, predGB))
print("RMSE:",np.sqrt(mean_squared_error(Y_test, predGB)))
# Checking cv score 

print(cross_val_score(GB,X,Y,cv=5).mean())
# Out:
# R2_Score: 0.9767098773734486
# MAE: 0.05676987470956841
# MSE: 0.019525404698164977
# RMSE: 0.13973333424120737
# 0.8581473254667052

# %% [markdown]
# # BaggingRegressor

# %%
# Checking R2 score for BaggingRegressor
from sklearn.ensemble import BaggingRegressor
BR=BaggingRegressor()
BR.fit(X_train,Y_train)

# prediction
predBR=BR.predict(X_test)
print('R2_Score:',r2_score(Y_test,predBR))
print('MAE:',mean_absolute_error(Y_test, predBR))
print('MSE:',mean_squared_error(Y_test, predBR))
print("RMSE:",np.sqrt(mean_squared_error(Y_test, predBR)))
# Checking cv score
print(cross_val_score(BR,X,Y,cv=5).mean())
# Out:
# R2_Score: 0.9840514558358321
# MAE: 0.026517794836008374
# MSE: 0.013370551290997906
# RMSE: 0.11563110001637927
# 0.8682286515287896

# %% [markdown]
# # AdaBoostRegressor

# %%
ABR=AdaBoostRegressor()

ABR.fit(X_train,Y_train)
# prediction
predABR=ABR.predict(X_test)
print('R2_Score:',r2_score(Y_test,predABR))
print('MAE:',mean_absolute_error(Y_test, predABR))
print('MSE:',mean_squared_error(Y_test, predABR))
print("RMSE:",np.sqrt(mean_squared_error(Y_test, predABR)))
# Checking cv score
print(cross_val_score(ABR,X,Y,cv=5).mean())
# Out:
# R2_Score: 0.920998323111769
# MAE: 0.1996231743766807
# MSE: 0.06623149812521112
# RMSE: 0.2573548097961472
# 0.8500451771032604

# %% [markdown]
# ##### I am selecting Bagging Regressor as my best model for hyper parameter tuning.

# %% [markdown]
# # Hyper parameter tuning

# %%
parameter={'n_estimators':[1,3,4,5],
          'n_jobs':[5,10,15,20,25],
          'verbose' : [10,20,30,40],
          'random_state':[100,150,200,250]}

# %%
GCV=GridSearchCV(BaggingRegressor(),parameter,cv=4)

# %%
GCV.fit(X_train,Y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ...

# %%
GCV.best_params_
# Out:
# {'n_estimators': 5, 'n_jobs': 5, 'random_state': 150, 'verbose': 10}

# %%
model2 = BaggingRegressor(n_estimators= 5, n_jobs= 5, random_state= 150, verbose= 10)
model2.fit(X_train, Y_train)
pred = model2.predict(X_test)
print("RMSE value:",np.sqrt(mean_squared_error(Y_test, pred)))
print('R2_Score:',r2_score(Y_test,pred)*100)
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:    5.7s remaining:    8.5s
# [Parallel(n_jobs=5)]: Done   3 out of   5 | elapsed:    5.8s remaining:    3.8s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:    6.1s remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:    6.1s finished
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Batch computation too fast (0.0154s.) Setting batch_size=2.
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   3 out of   5 | elapsed:    0.0s remaining:    0.0s
# RMSE value: 0.12168851591580877
# R2_Score: 98.23367376219393
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:    1.2s finished

# %% [markdown]
# # Saving the model

# %%
filename = "Final_Price_range_model.pkl"
pickle.dump(filename, open(filename,'wb'))

# %% [markdown]
# # Loading The Model

# %%
loadmodel = pickle.load(open('Final_Price_range_model.pkl', 'rb'))

# %%
pred = model2.predict(X_test)
b = np.array(Y_test)
final2 = pd.DataFrame({"Original":b,"Predicted":pred},index=range(len(b)))
final2
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Batch computation too fast (0.0113s.) Setting batch_size=2.
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   3 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:    0.0s finished
#       Original  Predicted
# 0            1        1.0
# 1            3        2.8
# 2            1        1.0
# 3            4        3.8
# 4            3        3.0
# ...        ...        ...
# 2861         2        2.0
# 2862         2        2.0
# 2863         2        2.0
# 2864         3        3.0
# 2865         1        1.0
#
# [2866 rows x 2 columns]

# %% [markdown]
# # Plot the result

# %%
plt.figure(figsize=(10,10))
sns.regplot(Y_test,pred,color='maroon')
plt.xlabel('Actual ',fontsize=15)
plt.ylabel('Predicted',fontsize=15)
plt.title("BaggingRegressor")
plt.show()

# %% [markdown]
# # Model1 has accuracy score as 80%
# # Model2 has accuracy score as 98.23%
